# %%
print('Hello World')

# %%
print('Thanatmet')
print('Thanarattanan')

# %%
print("5")
# Out:
# 5

# %%
print(1+4)
# Out:
# 5

# %% [markdown]
# string คือ กลุ่มของข้อความ ตัวอักษร '',""
#
# 5 เป็น ตัวเลข integer
#
# 1+4 นิพจน์ operand ตัวถูกกระทำ (1,4) ตัวดำเนินการ operator (+)
#
# 1+4 เป็น นิพจน์ expression
#
# '1+4' เป็น string
#
# '1' + '4' เป็นการทำ concatenation เป็นการทำ string ต่อกัน

# %%
print('1' + '4')
# Out:
# 14

# %%
print(1 + 4.0)
# Out:
# 5.0

# %%
x = 5
print(x)
print(type(x))
# Out:
# 5
# <class 'int'>

# %%
x
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
y= 5.
print(y)
print(type(y))
# Out:
# 5.0
# <class 'float'>

# %%
z = '5'
print(z)
print(type(z))
# Out:
# 5
# <class 'str'>

# %%
print(type('5.'))
# Out:
# <class 'str'>

# %%
print(type(5.))

# %% [markdown]
# ชนิดข้อมูล : int, float, string (str)
#
# ตรวจสอบด้วย type(xxx)

# %%
x = True
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>

# %%
x = False
print(x)
print(type(x))
# Out:
# False
# <class 'bool'>

# %%
print(type('True'))
# Out:
# <class 'str'>

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(type(False))
# Out:
# <class 'bool'>

# %%
x = 'False'
print(x)
print(type(x))
# Out:
# False
# <class 'str'>

# %% [markdown]
# ชนิข้อมูล : boolean (True,False) เป็นคำสงวน และต้องกำหนดเป็น Case sensitive

# %%
#List -> การเก็บข้อมูล []
ageList = [45,16,17,30]
print(ageList)
print(type(ageList))
print(ageList[0])
print(ageList[2])
print(ageList[3])
print(ageList[-1])
print(ageList[-0])
print(ageList[-4])
# Out:
# [45, 16, 17, 30]
# <class 'list'>
# 45
# 17
# 30
# 30
# 45
# 45

# %%
myDict ={ "a": 1, "b":2, "c": 3}
print(myDict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# list[],dictionary = { key1: value1, key2: value2, key3: value3, ... , keyN: valueN }, tuple(), set {}

# %%
print(myDict['a'])
print(myDict['b'])
print(myDict['c'])
print(myDict.keys())
for k in myDict.keys():
  print(k)
# Out:
# 1
# 2
# 3
# dict_keys(['a', 'b', 'c'])
# a
# b
# c

# %%
myDict ={ "a": [11,12], "b":[21,22], "c": [31,32]}
print(myDict)
# Out:
# {'a': [11, 12], 'b': [21, 22], 'c': [31, 32]}

# %%
print(myDict['a'])
print(myDict['a'][0])
print(myDict['b'])
print(myDict['b'][1])
print(myDict['c'])
print(myDict['c'][0])
# Out:
# [11, 12]
# 11
# [21, 22]
# 22
# [31, 32]
# 31

# %%
myTuple = (1,2,3)
print(myTuple)
print(type(myTuple))
print(myTuple[0])
# Out:
# (1, 2, 3)
# <class 'tuple'>
# 1

# %%
mySet = {5,45,20}
print(mySet)
print(type(mySet))
x = list(mySet)
print(x[0])
# Out:
# {5, 20, 45}
# <class 'set'>
# 5

# %%
x = 5
print(x)
print(type(x))

# %%
x = 5.0
print(x)
print(type(x))

# %%
print('Hello') #แสดงข้อความบนหน้าจอ
# Out:
# Hello

# %%
"""
x = 5.0
print(x)
print(type(x))
"""
# Out:
# '\nx = 5.0\nprint(x)\nprint(type(x))\n'
